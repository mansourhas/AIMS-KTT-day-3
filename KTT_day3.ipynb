# %%
from google.colab import userdata
gh_pat = userdata.get('GH_PAT')
# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()s
noteV = "v3"
repo_url = f"https://x-oauth-basic:{gh_pat}@github.com/mansourhas/AIMS-KTT-day-3.git"
# !git clone {repo_url}
# %cd hackathon
# Out:
# Cloning into 'AIMS-KTT-day-3'...
# remote: Enumerating objects: 376, done.
# remote: Counting objects: 100% (376/376), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 376 (delta 42), reused 370 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (376/376), 30.71 MiB | 17.55 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# [Errno 2] No such file or directory: 'hackathon'
# /content

# %%
# %cd /content/AIMS-KTT-day-3
# Out:
# /content/AIMS-KTT-day-3

# %%
# !pip install -U bitsandbytes>=0.46.1

# %%
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7 (delta 5), reused 7 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 1.30 KiB | 333.00 KiB/s, done.
# From https://github.com/mansourhas/AIMS-KTT-day-3
#    e4cc017..efec60d  main       -> origin/main
# Updating e4cc017..efec60d
# Fast-forward
#  process_log.md        |  8 +++----
#  src/socratic_tutor.py | 62 ++++++++++++---------------------------------------
#  2 files changed, 18 insertions(+), 52 deletions(-)

# %%
# !python src/socratic_tutor.py
# Out:
# Loading Quantized LLM (microsoft/Phi-3-mini-4k-instruct)...
# ...
# Loading weights: 100% 195/195 [00:26<00:00,  7.30it/s, Materializing param=model.norm.weight]
# Socratic Tutor LLM loaded successfully!
#
# --- Testing Socratic Tutor LLM ---
#
# Question: What is 4 apples plus 5 apples?
# Child said: 'nine' (Correct: True)
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'temperature', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=50) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Tutor Response: That's fantastic! You're doing great, keep up the good work!
#
# ...
